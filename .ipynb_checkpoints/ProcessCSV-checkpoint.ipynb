# %%
import pandas as pd
import os

# %%
def modify_df(file_name):
    """
    A function that reads file in csv format which was exported by LabelStudio.
    This function will transform given csv into dataframe that is more suitable for our sound classification.
    :param file_name: the string object that represents file name
    :returns: pandas.DataFrame object that represents data from the csv turned into our style.
    """
    data = pd.read_csv(file_name)
    
    file_names = list()
    start = list()
    end = list()
    class_name = list()

    for i in range(len(data)):
        instance = data.loc[i]
        cur_file_name = os.path.join(os.getcwd(), instance['audio'][1:])
        cur_class = eval(instance['intent'])  # Each values are recorded as str, so need eval
        cur_time_lines = eval(data.loc[i]['labels'])

        for j in range(len(cur_class)):
            cur_start = float(cur_time_lines[j]['start'])
            cur_end = float(cur_time_lines[j]['end'])

            start.append(cur_start)
            end.append(cur_end)
            class_name.append(cur_class[j])
            file_names.append(cur_file_name)

    modified_df = pd.DataFrame()
    modified_df['file_name'] = file_names
    modified_df['start'] = start
    modified_df['end'] = end
    modified_df['class'] = class_name
    
    return modified_df

# %%
from PIL import Image
from pydub import AudioSegment
import sqlite3
import string
import os

def generate_db():
    """
    A function that generates training_data/data.db file and initializes the table values.
    :return: None
    """
    conn = sqlite3.connect("./training_data/data.db")
    cur = conn.cursor()
    conn.execute("CREATE TABLE data(data_name TEXT, data_count INTEGER)")
    
    default_data = [(x, 0) for x in string.ascii_lowercase]
    default_data = default_data + [(str(x), 0) for x in range(0, 10, 1)]
    default_data.append(("null", 0))
    
    cur.executemany("INSERT INTO data VALUES(?, ?)", default_data)
    
    conn.commit()
    conn.close()
    
def get_data_count(data_name):
    """
    A function that gets data count from data.db for specific data_name
    :param data_name: the data_name to look for data counts
    :return: returns count of data_count value for provided data_name, returns -1 if data_name does not exist.
    """
    conn = sqlite3.connect("./training_data/data.db")
    cur = conn.cursor()
    cur.execute("SELECT data_count FROM data WHERE data_name=\"" + data_name + "\"")
    rows = cur.fetchall()
    try:
        return rows[0][0]
    except IndexError:
        return -1
    
    conn.close()
    
def update_data_count(data_name):
    """
    A function that adds 1 to the current data_count for specified data_name
    :param data_name: the data_name to update values into
    :return: None
    """
    before_count = get_data_count(data_name)    
    new_count = before_count + 1
    
    conn = sqlite3.connect("./training_data/data.db")
    cur = conn.cursor()
    cur.execute("UPDATE data SET data_count=" + str(new_count) + " WHERE data_name=\"" + data_name + "\"")
    conn.commit()
    conn.close()

def generate_all_directories():
    """
    A function that generates training_data directories.
    This will generate trainig_data/a~z and 0~9 directories.
    :return: None
    """
    dir_names = [x for x in string.ascii_lowercase]
    dir_names = dir_names + [str(x) for x in range(0, 10, 1)]

    training_data_path = os.path.join(os.getcwd(), "training_data")

    if not os.path.exists(training_data_path):  # generate training_data directory
        os.mkdir(training_data_path)
    
    for i in dir_names:  # generate subdirectories such as a ~ z, 0 ~ 9
        new_dir= os.path.join(training_data_path, i)
        if not os.path.exists(new_dir):
            os.mkdir(new_dir)

def process_df(df):
    """
    A function that splits each sound classifications from dataframe into different files
    :param df: the pandas.DataFrame object that represents single row of information.
    """
    file_name = df['file_name']
    new_audio = AudioSegment.from_wav(file_name)
    
    start = df['start'] * 1000
    end = df['end'] * 1000
    class_name = df['class']
    
    tmp_audio = new_audio[start:end]
    
    save_dir = os.path.join(os.getcwd(), "training_data", class_name)
    new_file_name = str(get_data_count(class_name)) + ".wav"
    new_file_name = os.path.join(save_dir, new_file_name)
    update_data_count(class_name)
    tmp_audio.export(new_file_name, format="wav")

# %%
df = modify_df("project-3-at-2022-06-23-07-16-c998cdd4.csv")

# %%
df
# Out:
#                                              file_name     start       end  \
# 0    /home/gooday2die/projects/Anti-Captcha-Sound/d...  0.018023  0.702913
# 1    /home/gooday2die/projects/Anti-Captcha-Sound/d...  1.111443  1.730247
# 2    /home/gooday2die/projects/Anti-Captcha-Sound/d...  1.850403  2.517269
# 3    /home/gooday2die/projects/Anti-Captcha-Sound/d...  2.865722  3.640728
# 4    /home/gooday2die/projects/Anti-Captcha-Sound/d...  3.893056  4.620000
# ..                                                 ...       ...       ...
# 992  /home/gooday2die/projects/Anti-Captcha-Sound/d...  0.019549  0.560398
# 993  /home/gooday2die/projects/Anti-Captcha-Sound/d...  1.251121  1.883198
# 994  /home/gooday2die/projects/Anti-Captcha-Sound/d...  2.515274  2.906250
# 995  /home/gooday2die/projects/Anti-Captcha-Sound/d...  3.440583  3.948850
# 996  /home/gooday2die/projects/Anti-Captcha-Sound/d...  4.378923  4.737317
#
#     class
# 0       5
# 1       t
# 2       j
# 3       t
# 4       n
# ..    ...
# 992     r
# 993     h
# 994     4
# 995     9
# 996     v
#
# [997 rows x 4 columns]

# %%
try:
    generate_db()
    print("[+] DB not found, generating a new one")
except sqlite3.OperationalError:  # when db already exists
    pass
generate_all_directories()

for i in range(len(df)):
    print("[+] Processing file " + str(i + 1) + " / " + str(len(df)))
    process_df(df.loc[i])
# Out:
# [+] DB not found, generating a new one
# [+] Processing file 1 / 997
# [+] Processing file 2 / 997
# [+] Processing file 3 / 997
# [+] Processing file 4 / 997
# [+] Processing file 5 / 997
# [+] Processing file 6 / 997
# [+] Processing file 7 / 997
# [+] Processing file 8 / 997
# [+] Processing file 9 / 997
# [+] Processing file 10 / 997
# [+] Processing file 11 / 997
# [+] Processing file 12 / 997
# [+] Processing file 13 / 997
# [+] Processing file 14 / 997
# [+] Processing file 15 / 997
# [+] Processing file 16 / 997
# [+] Processing file 17 / 997
# [+] Processing file 18 / 997
# [+] Processing file 19 / 997
# [+] Processing file 20 / 997
# [+] Processing file 21 / 997
# [+] Processing file 22 / 997
# [+] Processing file 23 / 997
# [+] Processing file 24 / 997
# [+] Processing file 25 / 997
# [+] Processing file 26 / 997
# [+] Processing file 27 / 997
# [+] Processing file 28 / 997
# [+] Processing file 29 / 997
# [+] Processing file 30 / 997
# [+] Processing file 31 / 997
# [+] Processing file 32 / 997
# [+] Processing file 33 / 997
# [+] Processing file 34 / 997
# [+] Processing file 35 / 997
# [+] Processing file 36 / 997
# [+] Processing file 37 / 997
# [+] Processing file 38 / 997
# [+] Processing file 39 / 997
# [+] Processing file 40 / 997
# [+] Processing file 41 / 997
# [+] Processing file 42 / 997
# [+] Processing file 43 / 997
# [+] Processing file 44 / 997
# [+] Processing file 45 / 997
# [+] Processing file 46 / 997
# [+] Processing file 47 / 997
# [+] Processing file 48 / 997
# [+] Processing file 49 / 997
# [+] Processing file 50 / 997
# [+] Processing file 51 / 997
# [+] Processing file 52 / 997
# [+] Processing file 53 / 997
# [+] Processing file 54 / 997
# [+] Processing file 55 / 997
# [+] Processing file 56 / 997
# [+] Processing file 57 / 997
# [+] Processing file 58 / 997
# [+] Processing file 59 / 997
# [+] Processing file 60 / 997
# [+] Processing file 61 / 997
# [+] Processing file 62 / 997
# [+] Processing file 63 / 997
# [+] Processing file 64 / 997
# [+] Processing file 65 / 997
# [+] Processing file 66 / 997
# [+] Processing file 67 / 997
# [+] Processing file 68 / 997
# [+] Processing file 69 / 997
# [+] Processing file 70 / 997
# [+] Processing file 71 / 997
# [+] Processing file 72 / 997
# [+] Processing file 73 / 997
# [+] Processing file 74 / 997
# [+] Processing file 75 / 997
# [+] Processing file 76 / 997
# [+] Processing file 77 / 997
# [+] Processing file 78 / 997
# [+] Processing file 79 / 997
# [+] Processing file 80 / 997
# [+] Processing file 81 / 997
# [+] Processing file 82 / 997
# [+] Processing file 83 / 997
# [+] Processing file 84 / 997
# [+] Processing file 85 / 997
# [+] Processing file 86 / 997
# [+] Processing file 87 / 997
# [+] Processing file 88 / 997
# [+] Processing file 89 / 997
# [+] Processing file 90 / 997
# [+] Processing file 91 / 997
# [+] Processing file 92 / 997
# [+] Processing file 93 / 997
# [+] Processing file 94 / 997
# [+] Processing file 95 / 997
# [+] Processing file 96 / 997
# [+] Processing file 97 / 997
# [+] Processing file 98 / 997
# [+] Processing file 99 / 997
# [+] Processing file 100 / 997
# [+] Processing file 101 / 997
# [+] Processing file 102 / 997
# [+] Processing file 103 / 997
# [+] Processing file 104 / 997
# [+] Processing file 105 / 997
# [+] Processing file 106 / 997
# [+] Processing file 107 / 997
# [+] Processing file 108 / 997
# [+] Processing file 109 / 997
# [+] Processing file 110 / 997
# [+] Processing file 111 / 997
# [+] Processing file 112 / 997
# [+] Processing file 113 / 997
# [+] Processing file 114 / 997
# [+] Processing file 115 / 997
# [+] Processing file 116 / 997
# [+] Processing file 117 / 997
# [+] Processing file 118 / 997
# [+] Processing file 119 / 997
# [+] Processing file 120 / 997
# [+] Processing file 121 / 997
# [+] Processing file 122 / 997
# [+] Processing file 123 / 997
# [+] Processing file 124 / 997
# [+] Processing file 125 / 997
# [+] Processing file 126 / 997
# [+] Processing file 127 / 997
# [+] Processing file 128 / 997
# [+] Processing file 129 / 997
# [+] Processing file 130 / 997
# [+] Processing file 131 / 997
# [+] Processing file 132 / 997
# [+] Processing file 133 / 997
# [+] Processing file 134 / 997
# [+] Processing file 135 / 997
# [+] Processing file 136 / 997
# [+] Processing file 137 / 997
# [+] Processing file 138 / 997
# [+] Processing file 139 / 997
# [+] Processing file 140 / 997
# [+] Processing file 141 / 997
# [+] Processing file 142 / 997
# [+] Processing file 143 / 997
# [+] Processing file 144 / 997
# [+] Processing file 145 / 997
# [+] Processing file 146 / 997
# [+] Processing file 147 / 997
# [+] Processing file 148 / 997
# [+] Processing file 149 / 997
# [+] Processing file 150 / 997
# [+] Processing file 151 / 997
# [+] Processing file 152 / 997
# [+] Processing file 153 / 997
# [+] Processing file 154 / 997
# [+] Processing file 155 / 997
# [+] Processing file 156 / 997
# [+] Processing file 157 / 997
# [+] Processing file 158 / 997
# [+] Processing file 159 / 997
# [+] Processing file 160 / 997
# [+] Processing file 161 / 997
# [+] Processing file 162 / 997
# [+] Processing file 163 / 997
# [+] Processing file 164 / 997
# [+] Processing file 165 / 997
# [+] Processing file 166 / 997
# [+] Processing file 167 / 997
# [+] Processing file 168 / 997
# [+] Processing file 169 / 997
# [+] Processing file 170 / 997
# [+] Processing file 171 / 997
# [+] Processing file 172 / 997
# [+] Processing file 173 / 997
# [+] Processing file 174 / 997
# [+] Processing file 175 / 997
# [+] Processing file 176 / 997
# [+] Processing file 177 / 997
# [+] Processing file 178 / 997
# [+] Processing file 179 / 997
# [+] Processing file 180 / 997
# [+] Processing file 181 / 997
# [+] Processing file 182 / 997
# [+] Processing file 183 / 997
# [+] Processing file 184 / 997
# [+] Processing file 185 / 997
# [+] Processing file 186 / 997
# [+] Processing file 187 / 997
# [+] Processing file 188 / 997
# [+] Processing file 189 / 997
# [+] Processing file 190 / 997
# [+] Processing file 191 / 997
# [+] Processing file 192 / 997
# [+] Processing file 193 / 997
# [+] Processing file 194 / 997
# [+] Processing file 195 / 997
# [+] Processing file 196 / 997
# [+] Processing file 197 / 997
# [+] Processing file 198 / 997
# [+] Processing file 199 / 997
# [+] Processing file 200 / 997
# [+] Processing file 201 / 997
# [+] Processing file 202 / 997
# [+] Processing file 203 / 997
# [+] Processing file 204 / 997
# [+] Processing file 205 / 997
# [+] Processing file 206 / 997
# [+] Processing file 207 / 997
# [+] Processing file 208 / 997
# [+] Processing file 209 / 997
# [+] Processing file 210 / 997
# [+] Processing file 211 / 997
# [+] Processing file 212 / 997
# [+] Processing file 213 / 997
# [+] Processing file 214 / 997
# [+] Processing file 215 / 997
# [+] Processing file 216 / 997
# [+] Processing file 217 / 997
# [+] Processing file 218 / 997
# [+] Processing file 219 / 997
# [+] Processing file 220 / 997
# [+] Processing file 221 / 997
# [+] Processing file 222 / 997
# [+] Processing file 223 / 997
# [+] Processing file 224 / 997
# [+] Processing file 225 / 997
# [+] Processing file 226 / 997
# [+] Processing file 227 / 997
# [+] Processing file 228 / 997
# [+] Processing file 229 / 997
# [+] Processing file 230 / 997
# [+] Processing file 231 / 997
# [+] Processing file 232 / 997
# [+] Processing file 233 / 997
# [+] Processing file 234 / 997
# [+] Processing file 235 / 997
# [+] Processing file 236 / 997
# [+] Processing file 237 / 997
# [+] Processing file 238 / 997
# [+] Processing file 239 / 997
# [+] Processing file 240 / 997
# [+] Processing file 241 / 997
# [+] Processing file 242 / 997
# [+] Processing file 243 / 997
# [+] Processing file 244 / 997
# [+] Processing file 245 / 997
# [+] Processing file 246 / 997
# [+] Processing file 247 / 997
# [+] Processing file 248 / 997
# [+] Processing file 249 / 997
# [+] Processing file 250 / 997
# [+] Processing file 251 / 997
# [+] Processing file 252 / 997
# [+] Processing file 253 / 997
# [+] Processing file 254 / 997
# [+] Processing file 255 / 997
# [+] Processing file 256 / 997
# [+] Processing file 257 / 997
# [+] Processing file 258 / 997
# [+] Processing file 259 / 997
# [+] Processing file 260 / 997
# [+] Processing file 261 / 997
# [+] Processing file 262 / 997
# [+] Processing file 263 / 997
# [+] Processing file 264 / 997
# [+] Processing file 265 / 997
# [+] Processing file 266 / 997
# [+] Processing file 267 / 997
# [+] Processing file 268 / 997
# [+] Processing file 269 / 997
# [+] Processing file 270 / 997
# [+] Processing file 271 / 997
# [+] Processing file 272 / 997
# [+] Processing file 273 / 997
# [+] Processing file 274 / 997
# [+] Processing file 275 / 997
# [+] Processing file 276 / 997
# [+] Processing file 277 / 997
# [+] Processing file 278 / 997
# [+] Processing file 279 / 997
# [+] Processing file 280 / 997
# [+] Processing file 281 / 997
# [+] Processing file 282 / 997
# [+] Processing file 283 / 997
# [+] Processing file 284 / 997
# [+] Processing file 285 / 997
# [+] Processing file 286 / 997
# [+] Processing file 287 / 997
# [+] Processing file 288 / 997
# [+] Processing file 289 / 997
# [+] Processing file 290 / 997
# [+] Processing file 291 / 997
# [+] Processing file 292 / 997
# [+] Processing file 293 / 997
# [+] Processing file 294 / 997
# [+] Processing file 295 / 997
# [+] Processing file 296 / 997
# [+] Processing file 297 / 997
# [+] Processing file 298 / 997
# [+] Processing file 299 / 997
# [+] Processing file 300 / 997
# [+] Processing file 301 / 997
# [+] Processing file 302 / 997
# [+] Processing file 303 / 997
# [+] Processing file 304 / 997
# [+] Processing file 305 / 997
# [+] Processing file 306 / 997
# [+] Processing file 307 / 997
# [+] Processing file 308 / 997
# [+] Processing file 309 / 997
# [+] Processing file 310 / 997
# [+] Processing file 311 / 997
# [+] Processing file 312 / 997
# [+] Processing file 313 / 997
# [+] Processing file 314 / 997
# [+] Processing file 315 / 997
# [+] Processing file 316 / 997
# [+] Processing file 317 / 997
# [+] Processing file 318 / 997
# [+] Processing file 319 / 997
# [+] Processing file 320 / 997
# [+] Processing file 321 / 997
# [+] Processing file 322 / 997
# [+] Processing file 323 / 997
# [+] Processing file 324 / 997
# [+] Processing file 325 / 997
# [+] Processing file 326 / 997
# [+] Processing file 327 / 997
# [+] Processing file 328 / 997
# [+] Processing file 329 / 997
# [+] Processing file 330 / 997
# [+] Processing file 331 / 997
# [+] Processing file 332 / 997
# [+] Processing file 333 / 997
# [+] Processing file 334 / 997
# [+] Processing file 335 / 997
# [+] Processing file 336 / 997
# [+] Processing file 337 / 997
# [+] Processing file 338 / 997
# [+] Processing file 339 / 997
# [+] Processing file 340 / 997
# [+] Processing file 341 / 997
# [+] Processing file 342 / 997
# [+] Processing file 343 / 997
# [+] Processing file 344 / 997
# [+] Processing file 345 / 997
# [+] Processing file 346 / 997
# [+] Processing file 347 / 997
# [+] Processing file 348 / 997
# [+] Processing file 349 / 997
# [+] Processing file 350 / 997
# [+] Processing file 351 / 997
# [+] Processing file 352 / 997
# [+] Processing file 353 / 997
# [+] Processing file 354 / 997
# [+] Processing file 355 / 997
# [+] Processing file 356 / 997
# [+] Processing file 357 / 997
# [+] Processing file 358 / 997
# [+] Processing file 359 / 997
# [+] Processing file 360 / 997
# [+] Processing file 361 / 997
# [+] Processing file 362 / 997
# [+] Processing file 363 / 997
# [+] Processing file 364 / 997
# [+] Processing file 365 / 997
# [+] Processing file 366 / 997
# [+] Processing file 367 / 997
# [+] Processing file 368 / 997
# [+] Processing file 369 / 997
# [+] Processing file 370 / 997
# [+] Processing file 371 / 997
# [+] Processing file 372 / 997
# [+] Processing file 373 / 997
# [+] Processing file 374 / 997
# [+] Processing file 375 / 997
# [+] Processing file 376 / 997
# [+] Processing file 377 / 997
# [+] Processing file 378 / 997
# [+] Processing file 379 / 997
# [+] Processing file 380 / 997
# [+] Processing file 381 / 997
# [+] Processing file 382 / 997
# [+] Processing file 383 / 997
# [+] Processing file 384 / 997
# [+] Processing file 385 / 997
# [+] Processing file 386 / 997
# [+] Processing file 387 / 997
# [+] Processing file 388 / 997
# [+] Processing file 389 / 997
# [+] Processing file 390 / 997
# [+] Processing file 391 / 997
# [+] Processing file 392 / 997
# [+] Processing file 393 / 997
# [+] Processing file 394 / 997
# [+] Processing file 395 / 997
# [+] Processing file 396 / 997
# [+] Processing file 397 / 997
# [+] Processing file 398 / 997
# [+] Processing file 399 / 997
# [+] Processing file 400 / 997
# [+] Processing file 401 / 997
# [+] Processing file 402 / 997
# [+] Processing file 403 / 997
# [+] Processing file 404 / 997
# [+] Processing file 405 / 997
# [+] Processing file 406 / 997
# [+] Processing file 407 / 997
# [+] Processing file 408 / 997
# [+] Processing file 409 / 997
# [+] Processing file 410 / 997
# [+] Processing file 411 / 997
# [+] Processing file 412 / 997
# [+] Processing file 413 / 997
# [+] Processing file 414 / 997
# [+] Processing file 415 / 997
# [+] Processing file 416 / 997
# [+] Processing file 417 / 997
# [+] Processing file 418 / 997
# [+] Processing file 419 / 997
# [+] Processing file 420 / 997
# [+] Processing file 421 / 997
# [+] Processing file 422 / 997
# [+] Processing file 423 / 997
# [+] Processing file 424 / 997
# [+] Processing file 425 / 997
# [+] Processing file 426 / 997
# [+] Processing file 427 / 997
# [+] Processing file 428 / 997
# [+] Processing file 429 / 997
# [+] Processing file 430 / 997
# [+] Processing file 431 / 997
# [+] Processing file 432 / 997
# [+] Processing file 433 / 997
# [+] Processing file 434 / 997
# [+] Processing file 435 / 997
# [+] Processing file 436 / 997
# [+] Processing file 437 / 997
# [+] Processing file 438 / 997
# [+] Processing file 439 / 997
# [+] Processing file 440 / 997
# [+] Processing file 441 / 997
# [+] Processing file 442 / 997
# [+] Processing file 443 / 997
# [+] Processing file 444 / 997
# [+] Processing file 445 / 997
# [+] Processing file 446 / 997
# [+] Processing file 447 / 997
# [+] Processing file 448 / 997
# [+] Processing file 449 / 997
# [+] Processing file 450 / 997
# [+] Processing file 451 / 997
# [+] Processing file 452 / 997
# [+] Processing file 453 / 997
# [+] Processing file 454 / 997
# [+] Processing file 455 / 997
# [+] Processing file 456 / 997
# [+] Processing file 457 / 997
# [+] Processing file 458 / 997
# [+] Processing file 459 / 997
# [+] Processing file 460 / 997
# [+] Processing file 461 / 997
# [+] Processing file 462 / 997
# [+] Processing file 463 / 997
# [+] Processing file 464 / 997
# [+] Processing file 465 / 997
# [+] Processing file 466 / 997
# [+] Processing file 467 / 997
# [+] Processing file 468 / 997
# [+] Processing file 469 / 997
# [+] Processing file 470 / 997
# [+] Processing file 471 / 997
# [+] Processing file 472 / 997
# [+] Processing file 473 / 997
# [+] Processing file 474 / 997
# [+] Processing file 475 / 997
# [+] Processing file 476 / 997
# [+] Processing file 477 / 997
# [+] Processing file 478 / 997
# [+] Processing file 479 / 997
# [+] Processing file 480 / 997
# [+] Processing file 481 / 997
# [+] Processing file 482 / 997
# [+] Processing file 483 / 997
# [+] Processing file 484 / 997
# [+] Processing file 485 / 997
# [+] Processing file 486 / 997
# [+] Processing file 487 / 997
# [+] Processing file 488 / 997
# [+] Processing file 489 / 997
# [+] Processing file 490 / 997
# [+] Processing file 491 / 997
# [+] Processing file 492 / 997
# [+] Processing file 493 / 997
# [+] Processing file 494 / 997
# [+] Processing file 495 / 997
# [+] Processing file 496 / 997
# [+] Processing file 497 / 997
# [+] Processing file 498 / 997
# [+] Processing file 499 / 997
# [+] Processing file 500 / 997
# [+] Processing file 501 / 997
# [+] Processing file 502 / 997
# [+] Processing file 503 / 997
# [+] Processing file 504 / 997
# [+] Processing file 505 / 997
# [+] Processing file 506 / 997
# [+] Processing file 507 / 997
# [+] Processing file 508 / 997
# [+] Processing file 509 / 997
# [+] Processing file 510 / 997
# [+] Processing file 511 / 997
# [+] Processing file 512 / 997
# [+] Processing file 513 / 997
# [+] Processing file 514 / 997
# [+] Processing file 515 / 997
# [+] Processing file 516 / 997
# [+] Processing file 517 / 997
# [+] Processing file 518 / 997
# [+] Processing file 519 / 997
# [+] Processing file 520 / 997
# [+] Processing file 521 / 997
# [+] Processing file 522 / 997
# [+] Processing file 523 / 997
# [+] Processing file 524 / 997
# [+] Processing file 525 / 997
# [+] Processing file 526 / 997
# [+] Processing file 527 / 997
# [+] Processing file 528 / 997
# [+] Processing file 529 / 997
# [+] Processing file 530 / 997
# [+] Processing file 531 / 997
# [+] Processing file 532 / 997
# [+] Processing file 533 / 997
# [+] Processing file 534 / 997
# [+] Processing file 535 / 997
# [+] Processing file 536 / 997
# [+] Processing file 537 / 997
# [+] Processing file 538 / 997
# [+] Processing file 539 / 997
# [+] Processing file 540 / 997
# [+] Processing file 541 / 997
# [+] Processing file 542 / 997
# [+] Processing file 543 / 997
# [+] Processing file 544 / 997
# [+] Processing file 545 / 997
# [+] Processing file 546 / 997
# [+] Processing file 547 / 997
# [+] Processing file 548 / 997
# [+] Processing file 549 / 997
# [+] Processing file 550 / 997
# [+] Processing file 551 / 997
# [+] Processing file 552 / 997
# [+] Processing file 553 / 997
# [+] Processing file 554 / 997
# [+] Processing file 555 / 997
# [+] Processing file 556 / 997
# [+] Processing file 557 / 997
# [+] Processing file 558 / 997
# [+] Processing file 559 / 997
# [+] Processing file 560 / 997
# [+] Processing file 561 / 997
# [+] Processing file 562 / 997
# [+] Processing file 563 / 997
# [+] Processing file 564 / 997
# [+] Processing file 565 / 997
# [+] Processing file 566 / 997
# [+] Processing file 567 / 997
# [+] Processing file 568 / 997
# [+] Processing file 569 / 997
# [+] Processing file 570 / 997
# [+] Processing file 571 / 997
# [+] Processing file 572 / 997
# [+] Processing file 573 / 997
# [+] Processing file 574 / 997
# [+] Processing file 575 / 997
# [+] Processing file 576 / 997
# [+] Processing file 577 / 997
# [+] Processing file 578 / 997
# [+] Processing file 579 / 997
# [+] Processing file 580 / 997
# [+] Processing file 581 / 997
# [+] Processing file 582 / 997
# [+] Processing file 583 / 997
# [+] Processing file 584 / 997
# [+] Processing file 585 / 997
# [+] Processing file 586 / 997
# [+] Processing file 587 / 997
# [+] Processing file 588 / 997
# [+] Processing file 589 / 997
# [+] Processing file 590 / 997
# [+] Processing file 591 / 997
# [+] Processing file 592 / 997
# [+] Processing file 593 / 997
# [+] Processing file 594 / 997
# [+] Processing file 595 / 997
# [+] Processing file 596 / 997
# [+] Processing file 597 / 997
# [+] Processing file 598 / 997
# [+] Processing file 599 / 997
# [+] Processing file 600 / 997
# [+] Processing file 601 / 997
# [+] Processing file 602 / 997
# [+] Processing file 603 / 997
# [+] Processing file 604 / 997
# [+] Processing file 605 / 997
# [+] Processing file 606 / 997
# [+] Processing file 607 / 997
# [+] Processing file 608 / 997
# [+] Processing file 609 / 997
# [+] Processing file 610 / 997
# [+] Processing file 611 / 997
# [+] Processing file 612 / 997
# [+] Processing file 613 / 997
# [+] Processing file 614 / 997
# [+] Processing file 615 / 997
# [+] Processing file 616 / 997
# [+] Processing file 617 / 997
# [+] Processing file 618 / 997
# [+] Processing file 619 / 997
# [+] Processing file 620 / 997
# [+] Processing file 621 / 997
# [+] Processing file 622 / 997
# [+] Processing file 623 / 997
# [+] Processing file 624 / 997
# [+] Processing file 625 / 997
# [+] Processing file 626 / 997
# [+] Processing file 627 / 997
# [+] Processing file 628 / 997
# [+] Processing file 629 / 997
# [+] Processing file 630 / 997
# [+] Processing file 631 / 997
# [+] Processing file 632 / 997
# [+] Processing file 633 / 997
# [+] Processing file 634 / 997
# [+] Processing file 635 / 997
# [+] Processing file 636 / 997
# [+] Processing file 637 / 997
# [+] Processing file 638 / 997
# [+] Processing file 639 / 997
# [+] Processing file 640 / 997
# [+] Processing file 641 / 997
# [+] Processing file 642 / 997
# [+] Processing file 643 / 997
# [+] Processing file 644 / 997
# [+] Processing file 645 / 997
# [+] Processing file 646 / 997
# [+] Processing file 647 / 997
# [+] Processing file 648 / 997
# [+] Processing file 649 / 997
# [+] Processing file 650 / 997
# [+] Processing file 651 / 997
# [+] Processing file 652 / 997
# [+] Processing file 653 / 997
# [+] Processing file 654 / 997
# [+] Processing file 655 / 997
# [+] Processing file 656 / 997
# [+] Processing file 657 / 997
# [+] Processing file 658 / 997
# [+] Processing file 659 / 997
# [+] Processing file 660 / 997
# [+] Processing file 661 / 997
# [+] Processing file 662 / 997
# [+] Processing file 663 / 997
# [+] Processing file 664 / 997
# [+] Processing file 665 / 997
# [+] Processing file 666 / 997
# [+] Processing file 667 / 997
# [+] Processing file 668 / 997
# [+] Processing file 669 / 997
# [+] Processing file 670 / 997
# [+] Processing file 671 / 997
# [+] Processing file 672 / 997
# [+] Processing file 673 / 997
# [+] Processing file 674 / 997
# [+] Processing file 675 / 997
# [+] Processing file 676 / 997
# [+] Processing file 677 / 997
# [+] Processing file 678 / 997
# [+] Processing file 679 / 997
# [+] Processing file 680 / 997
# [+] Processing file 681 / 997
# [+] Processing file 682 / 997
# [+] Processing file 683 / 997
# [+] Processing file 684 / 997
# [+] Processing file 685 / 997
# [+] Processing file 686 / 997
# [+] Processing file 687 / 997
# [+] Processing file 688 / 997
# [+] Processing file 689 / 997
# [+] Processing file 690 / 997
# [+] Processing file 691 / 997
# [+] Processing file 692 / 997
# [+] Processing file 693 / 997
# [+] Processing file 694 / 997
# [+] Processing file 695 / 997
# [+] Processing file 696 / 997
# [+] Processing file 697 / 997
# [+] Processing file 698 / 997
# [+] Processing file 699 / 997
# [+] Processing file 700 / 997
# [+] Processing file 701 / 997
# [+] Processing file 702 / 997
# [+] Processing file 703 / 997
# [+] Processing file 704 / 997
# [+] Processing file 705 / 997
# [+] Processing file 706 / 997
# [+] Processing file 707 / 997
# [+] Processing file 708 / 997
# [+] Processing file 709 / 997
# [+] Processing file 710 / 997
# [+] Processing file 711 / 997
# [+] Processing file 712 / 997
# [+] Processing file 713 / 997
# [+] Processing file 714 / 997
# [+] Processing file 715 / 997
# [+] Processing file 716 / 997
# [+] Processing file 717 / 997
# [+] Processing file 718 / 997
# [+] Processing file 719 / 997
# [+] Processing file 720 / 997
# [+] Processing file 721 / 997
# [+] Processing file 722 / 997
# [+] Processing file 723 / 997
# [+] Processing file 724 / 997
# [+] Processing file 725 / 997
# [+] Processing file 726 / 997
# [+] Processing file 727 / 997
# [+] Processing file 728 / 997
# [+] Processing file 729 / 997
# [+] Processing file 730 / 997
# [+] Processing file 731 / 997
# [+] Processing file 732 / 997
# [+] Processing file 733 / 997
# [+] Processing file 734 / 997
# [+] Processing file 735 / 997
# [+] Processing file 736 / 997
# [+] Processing file 737 / 997
# [+] Processing file 738 / 997
# [+] Processing file 739 / 997
# [+] Processing file 740 / 997
# [+] Processing file 741 / 997
# [+] Processing file 742 / 997
# [+] Processing file 743 / 997
# [+] Processing file 744 / 997
# [+] Processing file 745 / 997
# [+] Processing file 746 / 997
# [+] Processing file 747 / 997
# [+] Processing file 748 / 997
# [+] Processing file 749 / 997
# [+] Processing file 750 / 997
# [+] Processing file 751 / 997
# [+] Processing file 752 / 997
# [+] Processing file 753 / 997
# [+] Processing file 754 / 997
# [+] Processing file 755 / 997
# [+] Processing file 756 / 997
# [+] Processing file 757 / 997
# [+] Processing file 758 / 997
# [+] Processing file 759 / 997
# [+] Processing file 760 / 997
# [+] Processing file 761 / 997
# [+] Processing file 762 / 997
# [+] Processing file 763 / 997
# [+] Processing file 764 / 997
# [+] Processing file 765 / 997
# [+] Processing file 766 / 997
# [+] Processing file 767 / 997
# [+] Processing file 768 / 997
# [+] Processing file 769 / 997
# [+] Processing file 770 / 997
# [+] Processing file 771 / 997
# [+] Processing file 772 / 997
# [+] Processing file 773 / 997
# [+] Processing file 774 / 997
# [+] Processing file 775 / 997
# [+] Processing file 776 / 997
# [+] Processing file 777 / 997
# [+] Processing file 778 / 997
# [+] Processing file 779 / 997
# [+] Processing file 780 / 997
# [+] Processing file 781 / 997
# [+] Processing file 782 / 997
# [+] Processing file 783 / 997
# [+] Processing file 784 / 997
# [+] Processing file 785 / 997
# [+] Processing file 786 / 997
# [+] Processing file 787 / 997
# [+] Processing file 788 / 997
# [+] Processing file 789 / 997
# [+] Processing file 790 / 997
# [+] Processing file 791 / 997
# [+] Processing file 792 / 997
# [+] Processing file 793 / 997
# [+] Processing file 794 / 997
# [+] Processing file 795 / 997
# [+] Processing file 796 / 997
# [+] Processing file 797 / 997
# [+] Processing file 798 / 997
# [+] Processing file 799 / 997
# [+] Processing file 800 / 997
# [+] Processing file 801 / 997
# [+] Processing file 802 / 997
# [+] Processing file 803 / 997
# [+] Processing file 804 / 997
# [+] Processing file 805 / 997
# [+] Processing file 806 / 997
# [+] Processing file 807 / 997
# [+] Processing file 808 / 997
# [+] Processing file 809 / 997
# [+] Processing file 810 / 997
# [+] Processing file 811 / 997
# [+] Processing file 812 / 997
# [+] Processing file 813 / 997
# [+] Processing file 814 / 997
# [+] Processing file 815 / 997
# [+] Processing file 816 / 997
# [+] Processing file 817 / 997
# [+] Processing file 818 / 997
# [+] Processing file 819 / 997
# [+] Processing file 820 / 997
# [+] Processing file 821 / 997
# [+] Processing file 822 / 997
# [+] Processing file 823 / 997
# [+] Processing file 824 / 997
# [+] Processing file 825 / 997
# [+] Processing file 826 / 997
# [+] Processing file 827 / 997
# [+] Processing file 828 / 997
# [+] Processing file 829 / 997
# [+] Processing file 830 / 997
# [+] Processing file 831 / 997
# [+] Processing file 832 / 997
# [+] Processing file 833 / 997
# [+] Processing file 834 / 997
# [+] Processing file 835 / 997
# [+] Processing file 836 / 997
# [+] Processing file 837 / 997
# [+] Processing file 838 / 997
# [+] Processing file 839 / 997
# [+] Processing file 840 / 997
# [+] Processing file 841 / 997
# [+] Processing file 842 / 997
# [+] Processing file 843 / 997
# [+] Processing file 844 / 997
# [+] Processing file 845 / 997
# [+] Processing file 846 / 997
# [+] Processing file 847 / 997
# [+] Processing file 848 / 997
# [+] Processing file 849 / 997
# [+] Processing file 850 / 997
# [+] Processing file 851 / 997
# [+] Processing file 852 / 997
# [+] Processing file 853 / 997
# [+] Processing file 854 / 997
# [+] Processing file 855 / 997
# [+] Processing file 856 / 997
# [+] Processing file 857 / 997
# [+] Processing file 858 / 997
# [+] Processing file 859 / 997
# [+] Processing file 860 / 997
# [+] Processing file 861 / 997
# [+] Processing file 862 / 997
# [+] Processing file 863 / 997
# [+] Processing file 864 / 997
# [+] Processing file 865 / 997
# [+] Processing file 866 / 997
# [+] Processing file 867 / 997
# [+] Processing file 868 / 997
# [+] Processing file 869 / 997
# [+] Processing file 870 / 997
# [+] Processing file 871 / 997
# [+] Processing file 872 / 997
# [+] Processing file 873 / 997
# [+] Processing file 874 / 997
# [+] Processing file 875 / 997
# [+] Processing file 876 / 997
# [+] Processing file 877 / 997
# [+] Processing file 878 / 997
# [+] Processing file 879 / 997
# [+] Processing file 880 / 997
# [+] Processing file 881 / 997
# [+] Processing file 882 / 997
# [+] Processing file 883 / 997
# [+] Processing file 884 / 997
# [+] Processing file 885 / 997
# [+] Processing file 886 / 997
# [+] Processing file 887 / 997
# [+] Processing file 888 / 997
# [+] Processing file 889 / 997
# [+] Processing file 890 / 997
# [+] Processing file 891 / 997
# [+] Processing file 892 / 997
# [+] Processing file 893 / 997
# [+] Processing file 894 / 997
# [+] Processing file 895 / 997
# [+] Processing file 896 / 997
# [+] Processing file 897 / 997
# [+] Processing file 898 / 997
# [+] Processing file 899 / 997
# [+] Processing file 900 / 997
# [+] Processing file 901 / 997
# [+] Processing file 902 / 997
# [+] Processing file 903 / 997
# [+] Processing file 904 / 997
# [+] Processing file 905 / 997
# [+] Processing file 906 / 997
# [+] Processing file 907 / 997
# [+] Processing file 908 / 997
# [+] Processing file 909 / 997
# [+] Processing file 910 / 997
# [+] Processing file 911 / 997
# [+] Processing file 912 / 997
# [+] Processing file 913 / 997
# [+] Processing file 914 / 997
# [+] Processing file 915 / 997
# [+] Processing file 916 / 997
# [+] Processing file 917 / 997
# [+] Processing file 918 / 997
# [+] Processing file 919 / 997
# [+] Processing file 920 / 997
# [+] Processing file 921 / 997
# [+] Processing file 922 / 997
# [+] Processing file 923 / 997
# [+] Processing file 924 / 997
# [+] Processing file 925 / 997
# [+] Processing file 926 / 997
# [+] Processing file 927 / 997
# [+] Processing file 928 / 997
# [+] Processing file 929 / 997
# [+] Processing file 930 / 997
# [+] Processing file 931 / 997
# [+] Processing file 932 / 997
# [+] Processing file 933 / 997
# [+] Processing file 934 / 997
# [+] Processing file 935 / 997
# [+] Processing file 936 / 997
# [+] Processing file 937 / 997
# [+] Processing file 938 / 997
# [+] Processing file 939 / 997
# [+] Processing file 940 / 997
# [+] Processing file 941 / 997
# [+] Processing file 942 / 997
# [+] Processing file 943 / 997
# [+] Processing file 944 / 997
# [+] Processing file 945 / 997
# [+] Processing file 946 / 997
# [+] Processing file 947 / 997
# [+] Processing file 948 / 997
# [+] Processing file 949 / 997
# [+] Processing file 950 / 997
# [+] Processing file 951 / 997
# [+] Processing file 952 / 997
# [+] Processing file 953 / 997
# [+] Processing file 954 / 997
# [+] Processing file 955 / 997
# [+] Processing file 956 / 997
# [+] Processing file 957 / 997
# [+] Processing file 958 / 997
# [+] Processing file 959 / 997
# [+] Processing file 960 / 997
# [+] Processing file 961 / 997
# [+] Processing file 962 / 997
# [+] Processing file 963 / 997
# [+] Processing file 964 / 997
# [+] Processing file 965 / 997
# [+] Processing file 966 / 997
# [+] Processing file 967 / 997
# [+] Processing file 968 / 997
# [+] Processing file 969 / 997
# [+] Processing file 970 / 997
# [+] Processing file 971 / 997
# [+] Processing file 972 / 997
# [+] Processing file 973 / 997
# [+] Processing file 974 / 997
# [+] Processing file 975 / 997
# [+] Processing file 976 / 997
# [+] Processing file 977 / 997
# [+] Processing file 978 / 997
# [+] Processing file 979 / 997
# [+] Processing file 980 / 997
# [+] Processing file 981 / 997
# [+] Processing file 982 / 997
# [+] Processing file 983 / 997
# [+] Processing file 984 / 997
# [+] Processing file 985 / 997
# [+] Processing file 986 / 997
# [+] Processing file 987 / 997
# [+] Processing file 988 / 997
# [+] Processing file 989 / 997
# [+] Processing file 990 / 997
# [+] Processing file 991 / 997
# [+] Processing file 992 / 997
# [+] Processing file 993 / 997
# [+] Processing file 994 / 997
# [+] Processing file 995 / 997
# [+] Processing file 996 / 997
# [+] Processing file 997 / 997

# %%
from IPython.display import Audio 
Audio("/home/gooday2die/projects/Anti-Captcha/sounddooo/sounds/training_data/j/0.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
